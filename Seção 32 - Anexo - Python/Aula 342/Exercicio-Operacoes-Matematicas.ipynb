# %% [markdown]
# Questão 1: Ler dois números inteiros, executar e mostrar o resultado das seguintes operações: adição, subtração, multiplicação e divisão

# %%
def ler_inteiro(mensagem):
    """Lê um número inteiro com tratamento de erro."""
    while True:
        try:
            return int(input(mensagem))
        except ValueError:
            print("⚠️ Entrada inválida. Por favor, insira um número inteiro.\n")


def calculadora_de_Inteiros():
    """Calculadora de Operações Matemáticas entre Inteiros."""
    print("=== Calculadora de Operações Matemáticas entre Inteiros ===\n")

    primeiro_numero = ler_inteiro("Digite o primeiro número inteiro: ")
    segundo_numero = ler_inteiro("Digite o segundo número inteiro: ")

    # Operações básicas
    soma = primeiro_numero + segundo_numero
    subtracao = primeiro_numero - segundo_numero
    multiplicacao = primeiro_numero * segundo_numero
    potencia = primeiro_numero ** segundo_numero

    # Tratamento de divisão por zero
    try:
        divisao = primeiro_numero / segundo_numero
        divisao_inteira = primeiro_numero // segundo_numero
        resto_divisao = primeiro_numero % segundo_numero
    except ZeroDivisionError:
        divisao = divisao_inteira = resto_divisao = "❌ Não é possível dividir por zero."

    # Exibição dos resultados
    print("\n📊 Resultados das operações:")
    print(f"➕ Soma: {soma}")
    print(f"➖ Subtração: {subtracao}")
    print(f"✖️ Multiplicação: {multiplicacao}")
    print(f"➗ Divisão: {divisao}")
    print(f"// Divisão Inteira: {divisao_inteira}")
    print(f"% Resto da Divisão: {resto_divisao}")
    print(f"^ Potência: {potencia}")

    print("\n✅ Cálculos concluídos com sucesso!")

if __name__ == "__main__":
    try:
        calculadora_de_Inteiros()
    except Exception as e:
        print(f"\n⚠️ Ocorreu um erro inesperado: {e}")
# Out:
# === Calculadora de Operações Matemáticas entre Inteiros ===
#
# ⚠️ Entrada inválida. Por favor, insira um número inteiro.
#
# ⚠️ Entrada inválida. Por favor, insira um número inteiro.
#
#
# 📊 Resultados das operações:
# ➕ Soma: 3
# ➖ Subtração: -1
# ✖️ Multiplicação: 2
# ➗ Divisão: 0.5
# // Divisão Inteira: 0
# % Resto da Divisão: 1
# ^ Potência: 1
#
# ✅ Cálculos concluídos com sucesso!

# %% [markdown]
# Questão 2: Efetuar o cálculo da quantidade de litros de combustível gasto em uma viagem, utilizando um automóvel que faz 12 Km por litro. Para obter o cálculo, o usuário deve fornecer o tempo gasto na viagem e a velocidade média durante ela. Desta forma, será possível obter a distância percorrida com a fórmula DISTANCIA = TEMPO * VELOCIDADE. Tendo o valor da distância, basta calcular a quantidade de litros de combustível utilizada na viagem, com a fórmula: LITROS_USADOS = DISTANCIA / 12. O programa deve apresentar os valores da velocidade média, tempo gasto na viagem, a distância percorrida e a quantidade de litros utilizada na viagem

# %%
def ler_float_positivo(mensagem):
    """Lê um número float positivo com tratamento de erro e validação."""
    while True:
        try:
            valor = float(input(mensagem))
            if valor <= 0:
                print("⚠️ O valor deve ser maior que zero.\n")
                continue
            return valor
        except ValueError:
            print("⚠️ Entrada inválida. Por favor, insira um valor numérico.\n")

def calculadora_de_viagem():
    """Calcula distância, consumo e custo de combustível em uma viagem."""
    print("=== Calculadora de Custo e Distância de Viagem ===\n")
    
    tempo = ler_float_positivo("⏱️ Digite o tempo de viagem em horas: ")
    velocidade_media = ler_float_positivo("💨 Digite a velocidade média em km/h: ")
    preco_combustivel = ler_float_positivo("⛽ Digite o preço do litro do combustível: R$ ")

    distancia = tempo * velocidade_media
    consumo_combustivel = distancia / 12 # Consumo médio de 12 km/l
    custo_total = consumo_combustivel * preco_combustivel

    print("\n📊 Resultados da Viagem:")
    print("-" * 45)
    print(f"🕓 Tempo de viagem: {tempo:.2f} horas")
    print(f"🚗 Velocidade média: {velocidade_media:.2f} km/h")
    print(f"🛣️ Distância percorrida: {distancia:.2f} km")
    print(f"⛽ Combustível utilizado: {consumo_combustivel:.2f} litros")
    print(f"💰 Custo total estimado: R$ {custo_total:.2f}")
    print("-" * 45)
    print("\n✅ Cálculos concluídos com sucesso!")

if __name__ == "__main__":
    try:
        calculadora_de_viagem()
    except Exception as e:
        print(f"\n⚠️ Ocorreu um erro inesperado: {e}")
# Out:
# === Calculadora de Custo e Distância de Viagem ===
#
#
# 📊 Resultados da Viagem:
# ---------------------------------------------
# 🕓 Tempo de viagem: 2.00 horas
# 🚗 Velocidade média: 40.00 km/h
# 🛣️ Distância percorrida: 80.00 km
# ⛽ Combustível utilizado: 6.67 litros
# 💰 Custo total estimado: R$ 41.47
# ---------------------------------------------
#
# ✅ Cálculos concluídos com sucesso!
